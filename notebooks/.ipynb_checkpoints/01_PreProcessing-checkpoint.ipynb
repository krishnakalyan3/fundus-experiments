# %%
# Inspiration from 
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC3138933/

# %%
import cv2
import matplotlib.pyplot as plt
import matplotlib

import numpy as np

# %matplotlib inline

# %%
FUNDUS_PATH = '../data/images/21_training.tif'

# %%
image = cv2.imread(FUNDUS_PATH)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
print('size: {} shape: {}'.format(image.size, image.shape))
# Out:
# size: 989880 shape: (584, 565, 3)

# %%
#gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(image)
plt.show()

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
image.shape
# Out:
# (584, 565, 3)

# %%
# Extract the green channel

# %%
green = image[:,:,1]

# %%
plt.imshow(green, cmap = plt.cm.gray)
plt.show()

# %%
# CLAHE

# %%
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
cl1 = clahe.apply(green)

# %%
plt.imshow(cl1, cmap = plt.cm.gray)
plt.show()

# %%
# Image Denoising

# %%
dst = cv2.fastNlMeansDenoising(cl1)

# %%
plt.imshow(dst, cmap = plt.cm.gray)
plt.show()

# %%
# Another Denoising according to paper

# %%
kernel = np.ones((9,9),np.float32)/81
dst = cv2.filter2D(cl1,-1,kernel)

# %%
plt.imshow(dst, cmap = plt.cm.gray)
plt.show()

# %%
# Background Exclusion

# %%
cv2_subt = cv2.subtract(dst, image[:,:,1])

# %%
plt.imshow(cv2_subt > 1 , cmap = plt.cm.gray)
plt.show()

# %%
# TODO
# Work on background exclusion
# Error Measure

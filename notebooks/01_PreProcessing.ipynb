# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
FUNDUS_PATH = '/Users/krishnakalyan3/Educational/Fundus/data/image001.png'

# %%
img2 = cv2.imread(FUNDUS_PATH)
gray_image = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray_image)
plt.show()
